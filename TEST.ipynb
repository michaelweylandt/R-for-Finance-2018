# %% [markdown]
# # Test Notebook
#
# This notebook is not part of the course materials.

# %%
3 + 5
# Out:
# [1] 8

# %%
library(xts)
x <- xts(cumsum(rnorm(50)), Sys.Date() + 1:50)
print(head(x))
# Out:
#                  [,1]
# 2018-04-13  0.6030810
# 2018-04-14  2.6522110
# 2018-04-15  2.2271426
# 2018-04-16  1.6721224
# 2018-04-17  0.7467808
# 2018-04-18 -2.0167593

# %%
plot(x, main="My Series")
# Out:
# plot without title

# %%
library(ggplot2)
library(nycflights13)
data(flights)
# Out:
# Warning message:
# “package ‘nycflights13’ was built under R version 3.3.2”

# %%
ggplot(flights, aes(x=distance, y=arr_delay, color=carrier)) + 
    geom_point() + theme_bw() + theme(legend.position="bottom") + 
    xlab("Distance") + ylab("Delay") + ggtitle("Flight Info")
# Out:
# Warning message:
# “Removed 9430 rows containing missing values (geom_point).”
# plot without title
